# %% [markdown]
# # Pivot Table

# %% [markdown]
# ###  The levels in the Pivot table will be stored in multiIndex objects( hierarchical indexes) on the index and columns of the result DataFrame

# %%
import pandas as pd

# %%
data = pd.read_csv('matches.csv')

# %%
data
# Out:
#         id date  season        city                   team1  \
# 0      1.0  Yes    2017   Hyderabad     Sunrisers Hyderabad
# 1      2.0  Yes    2017        Pune          Mumbai Indians
# 2      3.0  Yes    2017      Rajkot           Gujarat Lions
# 3      NaN  Yes    2017      Indore  Rising Pune Supergiant
# 4      NaN  Yes    2017   Bangalore                     NaN
# ..     ...  ...     ...         ...                     ...
# 373  374.0   No    2012  Dharamsala         Kings XI Punjab
# 374  375.0   No    2012        Pune   Kolkata Knight Riders
# 375  376.0   No    2012   Hyderabad         Deccan Chargers
# 376  377.0   No    2012      Jaipur        Rajasthan Royals
# 377  378.0   No    2012        Pune   Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
data.pivot_table(index = 'season')
# Out:
#         dl_applied          id
# season
# 2008      0.034483   88.500000
# 2009      0.052632  146.000000
# 2010      0.000000  204.500000
# 2011      0.041096  271.000000
# 2012      0.000000  343.000000
# 2017      0.020408   33.096154

# %%
data.pivot_table(index = 'season', columns = 'city')
# Out:
#        dl_applied                                                        \
# city    Ahmedabad Bangalore Bloemfontein Cape Town Centurion Chandigarh
# season
# 2008          NaN  0.000000          NaN       NaN       NaN        0.0
# 2009          NaN       NaN          0.0  0.142857  0.083333        NaN
# 2010          0.0  0.000000          NaN       NaN       NaN        0.0
# 2011          NaN  0.166667          NaN       NaN       NaN        0.0
# 2012          NaN  0.000000          NaN       NaN       NaN        0.0
# 2017          NaN  0.166667          NaN       NaN       NaN        0.0
#
#                                              ...     id                     \
# city   Chennai Cuttack     Delhi Dharamsala  ... Kanpur   Kimberley  Kochi
# season                                       ...
# 2008       0.0     NaN  0.166667        NaN  ...    NaN         NaN    NaN
# 2009       NaN     NaN       NaN        NaN  ...    NaN  152.666667    NaN
# ...

# %%
data.pivot_table(index = 'season', columns = 'city', aggfunc='count')
# Out:
#             date                                                        \
# city   Ahmedabad Bangalore Bloemfontein Cape Town Centurion Chandigarh
# season
# 2008         NaN       7.0          NaN       NaN       NaN        7.0
# 2009         NaN       NaN          2.0       7.0      12.0        NaN
# 2010         4.0       7.0          NaN       NaN       NaN        5.0
# 2011         NaN       6.0          NaN       NaN       NaN        4.0
# 2012         NaN       7.0          NaN       NaN       NaN        6.0
# 2017         NaN       8.0          NaN       NaN       NaN        4.0
#
#                                          ... winner                          \
# city   Chennai Cuttack Delhi Dharamsala  ... Kanpur Kimberley Kochi Kolkata
# season                                   ...
# 2008       7.0     NaN   6.0        NaN  ...    NaN       NaN   NaN     7.0
# 2009       NaN     NaN   NaN        NaN  ...    NaN       3.0   NaN     NaN
# ...

# %%
data.pivot_table(index = 'season', columns = 'city', aggfunc='sum', fill_value='none')
# Out:
#        dl_applied                                                        \
# city    Ahmedabad Bangalore Bloemfontein Cape Town Centurion Chandigarh
# season
# 2008         none         0         none      none      none          0
# 2009         none      none            0         1         1       none
# 2010            0         0         none      none      none          0
# 2011         none         1         none      none      none          0
# 2012         none         0         none      none      none          0
# 2017         none         1         none      none      none          0
#
#                                          ...     id                          \
# city   Chennai Cuttack Delhi Dharamsala  ... Kanpur Kimberley Kochi Kolkata
# season                                   ...
# 2008         0    none     1       none  ...   none      none  none     642
# 2009      none    none  none       none  ...   none       458  none    none
# ...

# %%
data.pivot_table(index = 'season', columns = 'city', aggfunc='sum', fill_value='none',margins=True)
# Out:
#        dl_applied                                                        \
# city    Ahmedabad Bangalore Bloemfontein Cape Town Centurion Chandigarh
# season
# 2008         none         0         none      none      none          0
# 2009         none      none            0         1         1       none
# 2010            0         0         none      none      none          0
# 2011         none         1         none      none      none          0
# 2012         none         0         none      none      none          0
# 2017         none         1         none      none      none          0
# All             0         2            0         1         1          0
#
#                                          ...        id                       \
# city   Chennai Cuttack Delhi Dharamsala  ... Kimberley Kochi Kolkata Mumbai
# season                                   ...
# 2008         0    none     1       none  ...      none  none     642    952
# ...

# %% [markdown]
# # melt

# %% [markdown]
# ### Pandas melt function is used to transform or reshape data

# %%
pd.melt(data)
# Out:
#      variable                  value
# 0          id                      1
# 1          id                      2
# 2          id                      3
# 3          id                    NaN
# 4          id                    NaN
# ...       ...                    ...
# 4153   winner       Delhi Daredevils
# 4154   winner  Kolkata Knight Riders
# 4155   winner        Deccan Chargers
# 4156   winner         Mumbai Indians
# 4157   winner  Kolkata Knight Riders
#
# [4158 rows x 2 columns]

# %%
pd.melt(data, id_vars = 'city')
# Out:
#             city variable                  value
# 0      Hyderabad       id                      1
# 1           Pune       id                      2
# 2         Rajkot       id                      3
# 3         Indore       id                    NaN
# 4      Bangalore       id                    NaN
# ...          ...      ...                    ...
# 3775  Dharamsala   winner       Delhi Daredevils
# 3776        Pune   winner  Kolkata Knight Riders
# 3777   Hyderabad   winner        Deccan Chargers
# 3778      Jaipur   winner         Mumbai Indians
# 3779        Pune   winner  Kolkata Knight Riders
#
# [3780 rows x 3 columns]

# %%
pd.melt(data, id_vars = ['city','id'])
# Out:
#             city     id variable                  value
# 0      Hyderabad    1.0     date                    Yes
# 1           Pune    2.0     date                    Yes
# 2         Rajkot    3.0     date                    Yes
# 3         Indore    NaN     date                    Yes
# 4      Bangalore    NaN     date                    Yes
# ...          ...    ...      ...                    ...
# 3397  Dharamsala  374.0   winner       Delhi Daredevils
# 3398        Pune  375.0   winner  Kolkata Knight Riders
# 3399   Hyderabad  376.0   winner        Deccan Chargers
# 3400      Jaipur  377.0   winner         Mumbai Indians
# 3401        Pune  378.0   winner  Kolkata Knight Riders
#
# [3402 rows x 4 columns]

# %%
pd.melt(data, id_vars = ['city'], value_vars= ['team1'])
# Out:
#            city variable                   value
# 0     Hyderabad    team1     Sunrisers Hyderabad
# 1          Pune    team1          Mumbai Indians
# 2        Rajkot    team1           Gujarat Lions
# 3        Indore    team1  Rising Pune Supergiant
# 4     Bangalore    team1                     NaN
# ..          ...      ...                     ...
# 373  Dharamsala    team1         Kings XI Punjab
# 374        Pune    team1   Kolkata Knight Riders
# 375   Hyderabad    team1         Deccan Chargers
# 376      Jaipur    team1        Rajasthan Royals
# 377        Pune    team1   Kolkata Knight Riders
#
# [378 rows x 3 columns]

# %%
pd.melt(data, id_vars = ['city'], value_vars= ['team1'], var_name='Category')
# Out:
#            city Category                   value
# 0     Hyderabad    team1     Sunrisers Hyderabad
# 1          Pune    team1          Mumbai Indians
# 2        Rajkot    team1           Gujarat Lions
# 3        Indore    team1  Rising Pune Supergiant
# 4     Bangalore    team1                     NaN
# ..          ...      ...                     ...
# 373  Dharamsala    team1         Kings XI Punjab
# 374        Pune    team1   Kolkata Knight Riders
# 375   Hyderabad    team1         Deccan Chargers
# 376      Jaipur    team1        Rajasthan Royals
# 377        Pune    team1   Kolkata Knight Riders
#
# [378 rows x 3 columns]

# %%
pd.melt(data, id_vars = ['city'], value_vars= ['team1'], var_name='Category', value_name='Team1')
# Out:
#            city Category                   Team1
# 0     Hyderabad    team1     Sunrisers Hyderabad
# 1          Pune    team1          Mumbai Indians
# 2        Rajkot    team1           Gujarat Lions
# 3        Indore    team1  Rising Pune Supergiant
# 4     Bangalore    team1                     NaN
# ..          ...      ...                     ...
# 373  Dharamsala    team1         Kings XI Punjab
# 374        Pune    team1   Kolkata Knight Riders
# 375   Hyderabad    team1         Deccan Chargers
# 376      Jaipur    team1        Rajasthan Royals
# 377        Pune    team1   Kolkata Knight Riders
#
# [378 rows x 3 columns]

# %% [markdown]
# # Datetime_index

# %%
#data = pd.read_csv('matches.csv',parse_dates=['Date'])

# %%
data.dtypes
# Out:
# id               float64
# date              object
# season             int64
# city              object
# team1             object
# team2             object
# toss_winner       object
# toss_decision     object
# result            object
# dl_applied       float64
# winner            object
# dtype: object

# %%
type(data.date[0])
# Out:
# str
